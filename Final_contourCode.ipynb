# %% [markdown]
# # Importing important libraries

# %% [markdown]
# ##### first we will fetch the image using 'cv2.imread' function and plot the image using matplot library

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('/home/harveer/Desktop/Learner/final_year/Hand-written-text-recognizer-master/training_set/A/2.jpg')
plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# # Preprocessing on the image

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
img1,contours,hierarchy=cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
print(len(contours))
cv2.drawContours(img,contours,-1,(255,0,0),1)
plt.imshow(img,cmap='gray')
plt.show()
# Out:
# 1

# %% [markdown]
# # Fetching all the image at once

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
DATADIR='/home/harveer/Desktop/Learner/final_year/Hand-written-text-recognizer-master/training_set'
CATEGORIES=['A','B','C','D','E','F','G','H','I','J','K','L','M','N']
contour_A=[]
contour_B=[]
for category in CATEGORIES:
    path=os.path.join(DATADIR,category)
#      listdir() returns a list containing the names of the entries in the directory given by path
    for i in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,i))
        gray=cv2.cvtColor(img_array,cv2.COLOR_BGR2GRAY)
        ret,thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
        img1,contours,hierarchy=cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
        cnt=contours[0]
        k = cv2.convexHull(cnt)
#         k = cv2.isContourConvex(cnt)

#         M = cv2.moments(cnt)
#         cx = int(M['m10']/M['m00'])
#         cy = int(M['m01']/M['m00'])
#         perimeter = cv2.arcLength(cnt,True)

        if(category=='A'):
            contour_A.append(k)
        if(category=='B'):
            contour_B.append(k)
#             cv2.drawContours(img_array,cnt,-1,(255,0,0),1)
#             plt.imshow(img_array,cmap='gray')
#             plt.show()
print(contour_A)
print()
print(contour_B)
# Out:
# [array([[[29, 28]],
#
#        [[ 6, 29]],
#
#        [[ 3, 27]],
#
#        [[ 1, 25]],
#
#        [[ 0, 11]],
#
#        [[ 8,  0]],
#
#        [[10,  0]],
#
#        [[12,  1]],
#
#        [[15,  3]],
#
#        [[19,  7]],
#
#        [[23, 13]],
#
#        [[26, 18]],
#
#        [[27, 20]],
#
#        [[29, 25]]], dtype=int32), array([[[29, 28]],
#
#        [[28, 29]],
#
#        [[ 4, 29]],
#
#        [[ 3, 28]],
#
#        [[ 0, 17]],
#
#        [[ 0, 16]],
#
#        [[ 8,  4]],
#
#        [[11,  1]],
#
#        [[13,  0]],
#
#        [[16,  0]],
#
#        [[19,  2]],
#
#        [[21,  6]],
#
#        [[28, 21]],
#
#        [[29, 25]]], dtype=int32), array([[[29, 29]],
#
#        [[28, 29]],
#
#        [[ 0, 22]],
#
#        [[ 2, 10]],
#
#        [[10,  1]],
#
#        [[12,  0]],
#
#        [[13,  0]],
#
#        [[16,  1]],
#
#        [[28,  9]],
#
#        [[29, 27]]], dtype=int32), array([[[29, 13]],
#
#        [[28, 27]],
#
#        [[ 3, 29]],
#
#        [[ 1, 29]],
#
# ...
